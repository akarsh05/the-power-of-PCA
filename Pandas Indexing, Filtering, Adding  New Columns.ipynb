# %%
## Keep in mind
# iloc - index based selection. Index position, not its actual value, matters.
# loc - label based selection. Index value, not position, matters.
# differenc between iloc and loc
# loc incex includes last element as well
# iloc [0:10] -> 9 elements, loc[0:10] -> 10 elements
# for loc, this is benefitial when index is strings. Easier to define range as last element is included.
# both loc and iloc are row-first, column-second, opposite of native python
# can use lists, negative values for index

## adding new colums to a DF
# insert - add column to an existing dataframe
# assign - create a new dataframe with the new column

# %%
import pandas as pd

X = pd.read_csv("train.csv", index_col='Id')

X.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
X.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
X.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#first row, but result shown as a column
#X.iloc[0]
X.iloc[0].to_frame() #returns a dataframe, but the row is transposed as columm
#X.iloc[0,:]
# Out:
#                     1
# MSSubClass         60
# MSZoning           RL
# LotFrontage        65
# LotArea          8450
# Street           Pave
# ...               ...
# MoSold              2
# YrSold           2008
# SaleType           WD
# SaleCondition  Normal
# SalePrice      208500
#
# [80 rows x 1 columns]

# %%
X.iloc[0:1] #returns first row a dataframe
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
#
# [1 rows x 80 columns]

# %%
#first column
X.iloc[:,0]
#X.iloc[,0] #doesn't work
# Out:
# Id
# 1       60
# 2       20
# 3       60
# 4       70
# 5       60
#         ..
# 1456    60
# 1457    20
# 1458    70
# 1459    20
# 1460    20
# Name: MSSubClass, Length: 1460, dtype: int64

# %%
#all rows, first column

X.iloc[:,1]
# Out:
# Id
# 1       RL
# 2       RL
# 3       RL
# 4       RL
# 5       RL
#         ..
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# 1460    RL
# Name: MSZoning, Length: 1460, dtype: object

# %%
X.iloc[0:3,0:4]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea
# Id
# 1           60       RL         65.0     8450
# 2           20       RL         80.0     9600
# 3           60       RL         68.0    11250

# %%
#pass as list
X.iloc[[0,1,2],0:4]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea
# Id
# 1           60       RL         65.0     8450
# 2           20       RL         80.0     9600
# 3           60       RL         68.0    11250

# %%
# last 5 rows
X.iloc[-5:,:]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
# ...

# %%
# row with max SalePrice/LotArea
(X.SalePrice/X.LotArea).idxmax()
# Out:
# 957

# %%
X.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# iloc, bieing position based, starts from 0. Loc, based on value in our index column, starts from 1.
X.iloc[0]
# Out:
# MSSubClass           20
# MSZoning             RL
# LotFrontage          80
# LotArea            9600
# Street             Pave
#                   ...
# MoSold                5
# YrSold             2007
# SaleType             WD
# SaleCondition    Normal
# SalePrice        181500
# Name: 2, Length: 80, dtype: object

# %%
# iloc, bieing position based, starts from 0. Loc, based on value in our index column, starts from 1.
X.loc[1]
# Out:
# MSSubClass           60
# MSZoning             RL
# LotFrontage          65
# LotArea            8450
# Street             Pave
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        208500
# Name: 1, Length: 80, dtype: object

# %%
X.iloc[0:2]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
#
# [2 rows x 80 columns]

# %%
#X.loc[0:3]
X.loc[1:3]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
#
# [3 rows x 80 columns]

# %%
X.iloc[957].to_frame()
# Out:
#                   958
# MSSubClass         20
# MSZoning           RL
# LotFrontage        70
# LotArea          7420
# Street           Pave
# ...               ...
# MoSold              4
# YrSold           2007
# SaleType           WD
# SaleCondition  Normal
# SalePrice      132000
#
# [80 rows x 1 columns]

# %%
X.loc[957].to_frame()
# Out:
#                   957
# MSSubClass        160
# MSZoning           RM
# LotFrontage        24
# LotArea          1300
# Street           Pave
# ...               ...
# MoSold              5
# YrSold           2009
# SaleType           WD
# SaleCondition  Normal
# SalePrice      124000
#
# [80 rows x 1 columns]

# %%
X.loc[:,['MSSubClass','MSZoning']]
# Out:
#       MSSubClass MSZoning
# Id
# 1             60       RL
# 2             20       RL
# 3             60       RL
# 4             70       RL
# 5             60       RL
# ...          ...      ...
# 1456          60       RL
# 1457          20       RL
# 1458          70       RL
# 1459          20       RL
# 1460          20       RL
#
# [1460 rows x 2 columns]

# %%
#row with max SalePrice/LotArea

X.loc[(X.SalePrice/X.LotArea).idxmax()]
# Out:
# MSSubClass          160
# MSZoning             RM
# LotFrontage          24
# LotArea            1300
# Street             Pave
#                   ...
# MoSold                5
# YrSold             2009
# SaleType             WD
# SaleCondition    Normal
# SalePrice        124000
# Name: 957, Length: 80, dtype: object

# %%
bargain_idx = (X.SalePrice/X.LotArea).idxmin()
bargain_idx
# Out:
# 336

# %%
X.loc[bargain_idx]
# Out:
# MSSubClass          190
# MSZoning             RL
# LotFrontage         NaN
# LotArea          164660
# Street             Grvl
#                   ...
# MoSold                8
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        228950
# Name: 336, Length: 80, dtype: object

# %%
X.MSSubClass == 60
# Out:
# Id
# 1        True
# 2       False
# 3        True
# 4       False
# 5        True
#         ...
# 1456     True
# 1457    False
# 1458    False
# 1459    False
# 1460    False
# Name: MSSubClass, Length: 1460, dtype: bool

# %%
# filtering rows with MSSubclass = 60
X.loc[X.MSSubClass == 60]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 12            60       RL         85.0    11924   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# filtering using multiple conditions
X.loc[(X.MSSubClass == 60) & (X.MSZoning == 'FV')]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 106           60       FV         75.0     9375   Pave   NaN      Reg
# 159           60       FV        100.0    12552   Pave   NaN      Reg
# 213           60       FV         72.0     8640   Pave   NaN      Reg
# 257           60       FV         64.0     8791   Pave   NaN      IR1
# 271           60       FV         84.0    10728   Pave   NaN      Reg
# 298           60       FV         66.0     7399   Pave  Pave      IR1
# 318           60       FV         75.0     9000   Pave   NaN      Reg
# 378           60       FV        102.0    11143   Pave   NaN      IR1
# 400           60       FV         65.0     8125   Pave   NaN      Reg
# 410           60       FV         85.0    10800   Pave   NaN      Reg
# 454           60       FV         75.0     9000   Pave   NaN      Reg
# 461           60       FV         75.0     8004   Pave   NaN      IR1
# ...

# %%
X.MSZoning.unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
# Using isin

X.loc[X.MSZoning.isin(['RM','FV'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 16            45       RM         51.0     6120   Pave   NaN      Reg
# 22            45       RM         57.0     7449   Pave  Grvl      Reg
# 24           120       RM         44.0     4224   Pave   NaN      Reg
# 30            30       RM         60.0     6324   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1455          20       FV         62.0     7500   Pave  Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# missing SalePrice

X.loc[X.SalePrice.isnull()]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %%
# missing Fence

X.loc[X.Fence.isnull()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# not missing Fence

X.loc[X.Fence.notnull()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 15            20       RL          NaN    10920   Pave   NaN      IR1
# 16            45       RM         51.0     6120   Pave   NaN      Reg
# 20            20       RL         70.0     7560   Pave   NaN      Reg
# 22            45       RM         57.0     7449   Pave  Grvl      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
X.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
X.ReverseIndex = range(len(X),0,-1)
X.ReverseIndex
# Out:
# range(1460, 0, -1)

# %%
X.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
# if you don't use copy, the changes will be reflected on the original dataframe X as well.

X2 = X.copy()

# %%
# adding a new column to an exisiting dataframe at position 0
X2.insert(0,"ReverseIndex",range(len(X2),0,-1))

# %%
X2
# Out:
#       ReverseIndex  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# Id
# 1             1460          60       RL         65.0     8450   Pave   NaN
# 2             1459          20       RL         80.0     9600   Pave   NaN
# 3             1458          60       RL         68.0    11250   Pave   NaN
# 4             1457          70       RL         60.0     9550   Pave   NaN
# 5             1456          60       RL         84.0    14260   Pave   NaN
# ...            ...         ...      ...          ...      ...    ...   ...
# 1456             5          60       RL         62.0     7917   Pave   NaN
# 1457             4          20       RL         85.0    13175   Pave   NaN
# 1458             3          70       RL         66.0     9042   Pave   NaN
# 1459             2          20       RL         68.0     9717   Pave   NaN
# 1460             1          20       RL         75.0     9937   Pave   NaN
#
# ...

# %%
X
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# using assign to return a new dataframe with the new column column

X3 = X.assign(RevInd = range(len(X),0,-1))
X3
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# Id                                    ...
# ...
